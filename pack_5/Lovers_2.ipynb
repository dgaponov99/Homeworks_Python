# %%
import random

number_simulations = int(input("Введите число кругов симуляций: "))

meeting = 0


def simulation():
    global y, meeting
    bug = True
    number_check = random.randint(1, 5)
    for i in range(number_check):
        probability = random.randint(1, 100)
        if probability < 12:
            bug = False
            print("Баг обнаружен Клавдией на " + str(i + 1) + "-й проверке . Встречи не будет.")
            break
    if bug:
        print('Клавдия завершила проверку. Баг не обнаружен.')
        probability = random.randint(1, 100)
        if probability < 12:
            print('Кончтантин обнаружил баг. Встреча состоится')
            meeting += 1
        else:
            print('Константин не обнаружил баг. Встречи не будет')


for i in range(number_simulations):
    print(str(i) + "-я симуляция:")
    simulation()

print('Теоретическая вероятность встречи: 0,061424')
print('Симулятивная вероятность: %.6f' % (meeting / number_simulations))
# Out:
# Введите число кругов симуляций: 200
# 0-я симуляция:
# Клавдия завершила проверку. Баг не обнаружен.
# Константин не обнаружил баг. Встречи не будет
# 1-я симуляция:
# Клавдия завершила проверку. Баг не обнаружен.
# Константин не обнаружил баг. Встречи не будет
# 2-я симуляция:
# Клавдия завершила проверку. Баг не обнаружен.
# Константин не обнаружил баг. Встречи не будет
# 3-я симуляция:
# Клавдия завершила проверку. Баг не обнаружен.
# Константин не обнаружил баг. Встречи не будет
# 4-я симуляция:
# Клавдия завершила проверку. Баг не обнаружен.
# Константин не обнаружил баг. Встречи не будет
# 5-я симуляция:
# Клавдия завершила проверку. Баг не обнаружен.
# Константин не обнаружил баг. Встречи не будет
# 6-я симуляция:
# Баг обнаружен Клавдией на 1-й проверке . Встречи не будет.
# 7-я симуляция:
# Баг обнаружен Клавдией на 2-й проверке . Встречи не будет.
# 8-я симуляция:
# Баг обнаружен Клавдией на 2-й проверке . Встречи не будет.
# 9-я симуляция:
# ...
